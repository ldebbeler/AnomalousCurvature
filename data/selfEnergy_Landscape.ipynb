# %%
import h5py
import math
import bisect
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib
import matplotlib.font_manager
import matplotlib.pyplot as plt
matplotlib.font_manager._rebuild()
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})
matplotlib.rc('text', usetex=True)
matplotlib.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]
# for Palatino and other serif fonts use:
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Palatino"],
})
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')
import seaborn as sns

# %%
class Data:
    def __init__(self, file):
        self.at = np.array(file['SelfEnergy/at'])
        self.apos = np.array(file['SelfEnergy/apos'])
        self.aneg = np.array(file['SelfEnergy/aneg'])

# %%
class sePlots(Data):
    def __init__(self,file):
        Data.__init__(self,file)
        
    def plot(self):
        plt.plot(self.at,self.apos,label=r'$A_+$')
        plt.plot(self.at,self.aneg,label=r'$A_-$')
        plt.xlabel(r'$\alpha$',fontsize=20)
        plt.ylabel(r'$A_\pm$',fontsize=20)
        #plt.xlim([0.2,0.2])
        plt.ylim([0.0,2])
        plt.legend()
        plt.savefig('Graphics/aPlusMinus.pdf',bbox_inches="tight")
        plt.show()

# %%
foo = sePlots(h5py.File('SelfEnergy.h5','r'))

# %%
foo.plot()
